# %%
import pandas as pd

# %%
ref = pd.read_parquet("../saved_models/reference_data.parquet")
print(ref.columns)
print(ref.dtypes)
# Out:
# Index(['building_id', 'meter', 'site_id', 'primary_use', 'square_feet',
#        'air_temperature', 'cloud_coverage', 'dew_temperature',
#        'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction',
#        'wind_speed', 'day', 'month', 'week', 'hour', 'is_weekend',
#        'meter_reading'],
#       dtype='object')
# building_id            float16
# meter                  float16
# site_id                   int8
# primary_use           category
# square_feet              int32
# air_temperature        float16
# cloud_coverage         float16
# dew_temperature        float16
# precip_depth_1_hr      float16
# sea_level_pressure     float16
# wind_direction         float16
# wind_speed             float16
# day                    float16
# month                  float16
# week                   float16
# hour                      int8
# is_weekend                int8
# meter_reading          float32
# dtype: object

# %%
print(ref.head())
# Out:
#    building_id  meter  site_id          primary_use  square_feet  \
# 0        456.0    0.0        3      Public services        14125
# 1        771.0    1.0        6  Lodging/residential        82911
# 2        168.0    3.0        2            Education       183460
# 3        500.0    0.0        3            Education        99975
# 4       1036.0    0.0       12               Office        54207
#
#    air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 0        21.703125             0.0        18.296875           0.000000
# 1        10.601562             0.0         7.800781           0.000000
# 2         8.296875             2.0         2.800781           0.000000
# 3        20.593750             2.0        18.906250           0.000000
# 4        11.398438             8.0         7.300781           4.144531
#
#    sea_level_pressure  wind_direction  wind_speed   day  month  week  hour  \
# ...
